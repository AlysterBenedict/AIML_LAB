# %% [markdown]
# 6. Implement the non-parametric Locally Weighted Regression algorithm in order to fit data points. Select appropriate data set for your experiment and draw graphs.

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

np.random.seed(42)
X = np.linspace(0, 2 * np.pi, 100)
y = np.sin(X) + 0.1 * np.random.randn(100)

frac_value = 0.2

lowess_results = sm.nonparametric.lowess(y, X, frac=frac_value)

x_smoothed = lowess_results[:, 0]
y_smoothed = lowess_results[:, 1]

plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='red', label='Training Data', alpha=0.7)
plt.plot(x_smoothed, y_smoothed, color='blue', label=f'LOESS Fit (frac={frac_value})', linewidth=2)
plt.xlabel('X', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title('Locally Weighted Regression (using statsmodels.lowess)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(alpha=0.3)
plt.show()
